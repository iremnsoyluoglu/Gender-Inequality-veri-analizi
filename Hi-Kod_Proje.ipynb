# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data = pd.read_csv("GENDER_EMP_01052023104717861.csv") 
data.head()
# Out:
#    COU    Country   IND                                          Indicator  \
# 0  AUS  Australia  EMP8  Share of employed in temporary employment, by ...
# 1  AUS  Australia  EMP8  Share of employed in temporary employment, by ...
# 2  AUT    Austria  EMP8  Share of employed in temporary employment, by ...
# 3  AUT    Austria  EMP8  Share of employed in temporary employment, by ...
# 4  AUT    Austria  EMP8  Share of employed in temporary employment, by ...
#
#      SEX    Sex    AGE Age Group  TIME  Time Unit Code        Unit  \
# 0    MEN    Men  TOTAL     Total  2010  2010        PC  Percentage
# 1  WOMEN  Women  TOTAL     Total  2010  2010        PC  Percentage
# 2    MEN    Men  TOTAL     Total  1995  1995        PC  Percentage
# 3    MEN    Men  TOTAL     Total  2000  2000        PC  Percentage
# 4    MEN    Men  TOTAL     Total  2005  2005        PC  Percentage
#
#    PowerCode Code PowerCode  Reference Period Code  Reference Period  Value  \
# ...

# %%
data
# Out:
#        COU         Country   IND  \
# 0      AUS       Australia  EMP8
# 1      AUS       Australia  EMP8
# 2      AUT         Austria  EMP8
# 3      AUT         Austria  EMP8
# 4      AUT         Austria  EMP8
# ...    ...             ...   ...
# 3065   LTU       Lithuania  EMP8
# 3066   SVN        Slovenia  EMP8
# 3067   SVN        Slovenia  EMP8
# 3068  OAVG  OECD - Average  EMP8
# 3069  OAVG  OECD - Average  EMP8
#
#                                               Indicator    SEX    Sex    AGE  \
# 0     Share of employed in temporary employment, by ...    MEN    Men  TOTAL
# 1     Share of employed in temporary employment, by ...  WOMEN  Women  TOTAL
# 2     Share of employed in temporary employment, by ...    MEN    Men  TOTAL
# 3     Share of employed in temporary employment, by ...    MEN    Men  TOTAL
# 4     Share of employed in temporary employment, by ...    MEN    Men  TOTAL
# ...                                                 ...    ...    ...    ...
# ...

# %%
data.head(10)
# Out:
#    COU    Country   IND                                          Indicator  \
# 0  AUS  Australia  EMP8  Share of employed in temporary employment, by ...
# 1  AUS  Australia  EMP8  Share of employed in temporary employment, by ...
# 2  AUT    Austria  EMP8  Share of employed in temporary employment, by ...
# 3  AUT    Austria  EMP8  Share of employed in temporary employment, by ...
# 4  AUT    Austria  EMP8  Share of employed in temporary employment, by ...
# 5  AUT    Austria  EMP8  Share of employed in temporary employment, by ...
# 6  AUT    Austria  EMP8  Share of employed in temporary employment, by ...
# 7  AUT    Austria  EMP8  Share of employed in temporary employment, by ...
# 8  AUT    Austria  EMP8  Share of employed in temporary employment, by ...
# 9  AUT    Austria  EMP8  Share of employed in temporary employment, by ...
#
#      SEX    Sex    AGE Age Group  TIME  Time Unit Code        Unit  \
# 0    MEN    Men  TOTAL     Total  2010  2010        PC  Percentage
# ...

# %%
data.tail(10)
# Out:
#        COU         Country   IND  \
# 3060   EST         Estonia  EMP8
# 3061   EST         Estonia  EMP8
# 3062   LVA          Latvia  EMP8
# 3063   LVA          Latvia  EMP8
# 3064   LTU       Lithuania  EMP8
# 3065   LTU       Lithuania  EMP8
# 3066   SVN        Slovenia  EMP8
# 3067   SVN        Slovenia  EMP8
# 3068  OAVG  OECD - Average  EMP8
# 3069  OAVG  OECD - Average  EMP8
#
#                                               Indicator    Sex Age Group  \
# 3060  Share of employed in temporary employment, by ...    Men     55-64
# 3061  Share of employed in temporary employment, by ...  Women     55-64
# 3062  Share of employed in temporary employment, by ...    Men     55-64
# 3063  Share of employed in temporary employment, by ...  Women     55-64
# 3064  Share of employed in temporary employment, by ...    Men     55-64
# 3065  Share of employed in temporary employment, by ...  Women     55-64
# 3066  Share of employed in temporary employment, by ...    Men     55-64
# ...

# %%
data[["Flags"]].isnull().sum()
# Out:
# Flags    3070
# dtype: int64

# %%
data=data.drop(["SEX","AGE","TIME","Flags","Reference Period Code","Reference Period","Flag Codes"],axis=1)  
data
# Out:
#        COU         Country   IND  \
# 0      AUS       Australia  EMP8
# 1      AUS       Australia  EMP8
# 2      AUT         Austria  EMP8
# 3      AUT         Austria  EMP8
# 4      AUT         Austria  EMP8
# ...    ...             ...   ...
# 3065   LTU       Lithuania  EMP8
# 3066   SVN        Slovenia  EMP8
# 3067   SVN        Slovenia  EMP8
# 3068  OAVG  OECD - Average  EMP8
# 3069  OAVG  OECD - Average  EMP8
#
#                                               Indicator    Sex Age Group  \
# 0     Share of employed in temporary employment, by ...    Men     Total
# 1     Share of employed in temporary employment, by ...  Women     Total
# 2     Share of employed in temporary employment, by ...    Men     Total
# 3     Share of employed in temporary employment, by ...    Men     Total
# 4     Share of employed in temporary employment, by ...    Men     Total
# ...                                                 ...    ...       ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3070 entries, 0 to 3069
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   COU             3070 non-null   object
#  1   Country         3070 non-null   object
#  2   IND             3070 non-null   object
#  3   Indicator       3070 non-null   object
#  4   Sex             3070 non-null   object
#  5   Age Group       3070 non-null   object
#  6   Time            3070 non-null   int64
#  7   Unit Code       3070 non-null   object
#  8   Unit            3070 non-null   object
#  9   PowerCode Code  3070 non-null   int64
#  10  PowerCode       3070 non-null   object
#  11  Value           3070 non-null   float64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 287.9+ KB

# %%
data.isnull().sum()
# Out:
# COU               0
# Country           0
# IND               0
# Indicator         0
# Sex               0
# Age Group         0
# Time              0
# Unit Code         0
# Unit              0
# PowerCode Code    0
# PowerCode         0
# Value             0
# dtype: int64

# %%
data.head()
# Out:
#    COU    Country   IND                                          Indicator  \
# 0  AUS  Australia  EMP8  Share of employed in temporary employment, by ...
# 1  AUS  Australia  EMP8  Share of employed in temporary employment, by ...
# 2  AUT    Austria  EMP8  Share of employed in temporary employment, by ...
# 3  AUT    Austria  EMP8  Share of employed in temporary employment, by ...
# 4  AUT    Austria  EMP8  Share of employed in temporary employment, by ...
#
#      Sex Age Group  Time Unit Code        Unit  PowerCode Code PowerCode  \
# 0    Men     Total  2010        PC  Percentage               0     Units
# 1  Women     Total  2010        PC  Percentage               0     Units
# 2    Men     Total  1995        PC  Percentage               0     Units
# 3    Men     Total  2000        PC  Percentage               0     Units
# 4    Men     Total  2005        PC  Percentage               0     Units
#
#    Value
# 0    4.4
# 1    6.2
# 2    5.7
# 3    7.6
# 4    9.2

# %%
#data= data.rename(columns={}) sütun isimlerini değiştirme

# %%
data["Time"]=data["Time"].astype("int64")
data["Value"]=data["Value"].astype("float32")  
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3070 entries, 0 to 3069
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   COU             3070 non-null   object
#  1   Country         3070 non-null   object
#  2   IND             3070 non-null   object
#  3   Indicator       3070 non-null   object
#  4   Sex             3070 non-null   object
#  5   Age Group       3070 non-null   object
#  6   Time            3070 non-null   int64
#  7   Unit Code       3070 non-null   object
#  8   Unit            3070 non-null   object
#  9   PowerCode Code  3070 non-null   int64
#  10  PowerCode       3070 non-null   object
#  11  Value           3070 non-null   float32
# dtypes: float32(1), int64(2), object(9)
# memory usage: 275.9+ KB

# %%
data.describe().T
# Out:
#                  count         mean        std     min     25%     50%  \
# Time            3070.0  2012.337785   8.694157  1990.0  2005.0  2016.0
# PowerCode Code  3070.0     0.000000   0.000000     0.0     0.0     0.0
# Value           3070.0    16.336578  15.018867     0.6     6.4    10.8
#
#                      75%          max
# Time            2019.000  2021.000000
# PowerCode Code     0.000     0.000000
# Value             21.875    85.900002

# %%
data['Country'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Czech Republic',
#        'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Hungary',
#        'Iceland', 'Ireland', 'Italy', 'Japan', 'Korea', 'Luxembourg',
#        'Mexico', 'Netherlands', 'Norway', 'Poland', 'Portugal',
#        'Slovak Republic', 'Spain', 'Sweden', 'Switzerland', 'Türkiye',
#        'United Kingdom', 'United States', 'Chile', 'Estonia', 'Russia',
#        'Slovenia', 'OECD - Average', 'Lithuania', 'Latvia', 'Costa Rica',
#        'Colombia'], dtype=object)

# %%
data['Sex'].unique()
# Out:
# array(['Men', 'Women'], dtype=object)

# %%
data["Age Group"].unique()
# Out:
# array(['Total', '15-24', '55-64', '25-54'], dtype=object)

# %%
data.groupby('Country')[['COU']].count().reset_index()
# Out:
#             Country  COU
# 0         Australia   32
# 1           Austria   88
# 2           Belgium   96
# 3            Canada   80
# 4             Chile   64
# 5          Colombia   72
# 6        Costa Rica   64
# 7    Czech Republic   88
# 8           Denmark   96
# 9           Estonia   80
# 10          Finland   80
# 11           France   96
# 12          Germany   96
# 13           Greece   96
# 14          Hungary   80
# 15          Iceland   88
# 16          Ireland   96
# 17            Italy   96
# 18            Japan   96
# 19            Korea   72
# 20           Latvia   80
# 21        Lithuania   80
# 22       Luxembourg   86
# 23           Mexico   16
# 24      Netherlands   96
# 25           Norway   80
# 26   OECD - Average   96
# 27           Poland   72
# 28         Portugal   96
# 29           Russia   72
# 30  Slovak Republic   88
# 31         Slovenia   80
# 32            Spain   96
# 33           Sweden   80
# 34      Switzerland   80
# 35          Türkiye   96
# ...

# %%
data[data['Sex']=="Women"]
# Out:
#        COU         Country   IND  \
# 1      AUS       Australia  EMP8
# 6      AUT         Austria  EMP8
# 7      AUT         Austria  EMP8
# 8      AUT         Austria  EMP8
# 9      AUT         Austria  EMP8
# ...    ...             ...   ...
# 3061   EST         Estonia  EMP8
# 3063   LVA          Latvia  EMP8
# 3065   LTU       Lithuania  EMP8
# 3067   SVN        Slovenia  EMP8
# 3069  OAVG  OECD - Average  EMP8
#
#                                               Indicator    Sex Age Group  \
# 1     Share of employed in temporary employment, by ...  Women     Total
# 6     Share of employed in temporary employment, by ...  Women     Total
# 7     Share of employed in temporary employment, by ...  Women     Total
# 8     Share of employed in temporary employment, by ...  Women     Total
# 9     Share of employed in temporary employment, by ...  Women     Total
# ...                                                 ...    ...       ...
# ...

# %%
data[data['Sex']=="Men"]
# Out:
#        COU         Country   IND  \
# 0      AUS       Australia  EMP8
# 2      AUT         Austria  EMP8
# 3      AUT         Austria  EMP8
# 4      AUT         Austria  EMP8
# 5      AUT         Austria  EMP8
# ...    ...             ...   ...
# 3060   EST         Estonia  EMP8
# 3062   LVA          Latvia  EMP8
# 3064   LTU       Lithuania  EMP8
# 3066   SVN        Slovenia  EMP8
# 3068  OAVG  OECD - Average  EMP8
#
#                                               Indicator  Sex Age Group  Time  \
# 0     Share of employed in temporary employment, by ...  Men     Total  2010
# 2     Share of employed in temporary employment, by ...  Men     Total  1995
# 3     Share of employed in temporary employment, by ...  Men     Total  2000
# 4     Share of employed in temporary employment, by ...  Men     Total  2005
# 5     Share of employed in temporary employment, by ...  Men     Total  2010
# ...                                                 ...  ...       ...   ...
# ...

# %%
data_womenandman=data.groupby("Sex")[["Value"]].mean() 
data_womenandman
# Out:
#            Value
# Sex
# Men    15.702608
# Women  16.969727

# %%
data_ayrm=data.groupby(["Sex","Country"])[["Value"]].mean()  
data_ayrm
# Out:
#                           Value
# Sex   Country
# Men   Australia        4.700000
#       Austria         12.931818
#       Belgium         12.452084
#       Canada          15.075000
#       Chile           31.278126
# ...                         ...
# Women Sweden          24.577499
#       Switzerland     18.150000
#       Türkiye         16.941668
#       United Kingdom   7.718750
#       United States    5.016667
#
# [76 rows x 1 columns]

# %%
data_date=data.groupby(["Country","Time","Age Group","Sex"])[["Value"]].mean().reset_index()  
data_date
# Out:
#             Country  Time Age Group    Sex  Value
# 0         Australia  2010     15-24    Men    5.4
# 1         Australia  2010     15-24  Women    5.4
# 2         Australia  2010     25-54    Men    3.9
# 3         Australia  2010     25-54  Women    6.6
# 4         Australia  2010     55-64    Men    4.9
# ...             ...   ...       ...    ...    ...
# 3065  United States  2017     25-54  Women    3.0
# 3066  United States  2017     55-64    Men    2.8
# 3067  United States  2017     55-64  Women    3.0
# 3068  United States  2017     Total    Men    4.1
# 3069  United States  2017     Total  Women    3.8
#
# [3070 rows x 5 columns]

# %%
px.bar(data_date,x ='Country',y="Value")

# %%
px.line(data_date, x = "Country", y = "Value", color="Sex")

# %%
sns.heatmap(data_date.pivot_table(index='Sex', columns='Country', values='Value')) 
plt.show()

# %%
sns.barplot(data_date, x='Age Group', y='Value') 
plt.show()

# %%
sns.boxplot(data_date, x='Sex', y='Value', hue='Time') 
plt.show()

# %%
px.bar(data_date, x="Country", y="Value",color="Sex")

# %%
plt.figure(figsize=(12,7))
sns.barplot(data_date , x="Value", y="Country",hue="Sex")
# Out:
# <Axes: xlabel='Value', ylabel='Country'>

# %%
px.bar(data_date,x = "Sex",y="Value")

# %%
px.line(data_date, x = "Country", y = "Age Group", color="Time")

# %%
px.bar(data_date,x = "Country",y="Age Group")

# %%
#     Sonuç olarak Ekonomik Kalkınma ve İşbirliği Örgütünün 1990-2021 yılları arasında 54 ülke ve 8 farklı yaş grubundan elde edilmiş bu veriler sayesinde aradan geçen 30 küsür 
#  yıllık sürede kadınların ve erkeklerin geçici istihdam durumlarını analiz ettik. Bunu 10 farklı görselleştirme ve çeşitli tablolarla size sunmaktı amacımız.

#      Bunların toplamında edindiğimiz bilgiler:
#  -Kadınlar ve erkeklerin iş istihdamı ülkeden ülkeye fazlasıyla değişmektedir.
#  -Genel ortalamaya göre kadınlar iş dünyasına geç atılmış ama hızlı bir ilerleyiş içerisindedir.Erkekler ise erken atılmış ama ilerleyiş biçimleri yavaştır.
#  -Gelişmiş sayılan çoğu ülkenin verilerinde kadınlar ve erkeklerin istihdam oranı birbirine çok yakınken, gelişmekte olan ülkelerde bu durum biraz daha karışıktır. 
#       Yani inişli ve çıkışlı bir durum göstermektedir.
#  -Bu grafiklerden elde ettiğimiz farklı sonuçlardan biri de istihdam oranları cinsiyet farketmeksizin karışık bir durumdur.Yani geçen sene arterken bu sene azalabiliyor 
#        veya tam tersi olabiliyor.
